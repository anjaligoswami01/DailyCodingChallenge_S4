# %% [markdown]
# <a href="https://colab.research.google.com/github/anjaligoswami01/DailyCodingChallenge_S4/blob/main/day2/day2_textprocessingpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Beginner-friendly: simple input/output

text = input("Enter something: ")
print("You entered:", text)
# Out:
# Enter something: hello world
# You entered: hello world

# %%
# Read a sentence from user
sentence = input("Enter a sentence: ")

# Convert to lowercase
sentence = sentence.lower()

# Split sentence into words
words = sentence.split()

# Create dictionary to store frequency
frequency = {}

# Count each word
for word in words:
    frequency[word] = frequency.get(word, 0) + 1

# Print result
print("Word Frequency:")
for word in frequency:
    print(f"{word} : {frequency[word]}")
# Out:
# Enter a sentence: all days are not good days some are bad
# Word Frequency:
# all : 1
# days : 2
# are : 2
# not : 1
# good : 1
# some : 1
# bad : 1

# %%
# Clean text using regex

import re

text = input("Enter text: ")

# Convert to lowercase
text = text.lower()

# Remove punctuation
text = re.sub(r'[^\w\s]', '', text)

# Normalize multiple spaces into one
text = re.sub(r'\s+', ' ', text)

# Remove leading/trailing spaces
text = text.strip()

print("Cleaned Text:")
print(text)
# Out:
# Enter text: Hey SUCH a sMol world !!
# Cleaned Text:
# hey such a smol world
